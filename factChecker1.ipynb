# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
classes = ['Conservatives', 'Liberals']    
import sklearn.datasets.base
data_path = "dataset"
article_train = sklearn.datasets.load_files(data_path, description=None, categories=classes, load_content=True, shuffle=True, encoding='utf-8', decode_error='strict', random_state=42)

# %%
print(len(article_train.filenames))
print(article_train.target_names)
# print(article_train.data[0].split("\n")[5:])
# Out:
# 2161
# ['Conservatives', 'Liberals']

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(article_train.data)
print(X_train_counts.shape)
# Out:
# (2161, 58742)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (2161, 58742)

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, article_train.target)

# %%
>>> from sklearn.pipeline import Pipeline
>>> text_clf = Pipeline([('vect', CountVectorizer()),
...                      ('tfidf', TfidfTransformer()),
...                      ('clf', MultinomialNB()),
... ])
text_clf = text_clf.fit(article_train.data, article_train.target)

# %%
for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, article_train.target_names[category]))
# Out:
# 'anders said the president was more concerned with the ongoing plans for the possible summit with' => Conservatives
# 'Ukrainian police reported that an unidentified gunman shot and killed him in the entryway to his apartment in Kiev, an apparent murder that bore the hallmarks of a contract hit, and appeared to be part of a wave of targeted killings in Ukraine directed at opponents of Moscow' => Conservatives

# %%
docs_new = ["On Tuesday morning, the man stabbed two policewomen from behind before stealing their service weapons and using them to kill the officers.", r"Ukrainian police reported that an unidentified gunman shot and killed him in the entryway to his apartment in Kiev, an apparent murder that bore the hallmarks of a contract hit, and appeared to be part of a wave of targeted killings in Ukraine directed at opponents of Moscow"]
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

# %%
predicted = clf.predict(X_new_tfidf)

# %%
for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, article_train.target_names[category]))
# Out:
# 'On Tuesday morning, the man stabbed two policewomen from behind before stealing their service weapons and using them to kill the officers.' => Conservatives
# 'Ukrainian police reported that an unidentified gunman shot and killed him in the entryway to his apartment in Kiev, an apparent murder that bore the hallmarks of a contract hit, and appeared to be part of a wave of targeted killings in Ukraine directed at opponents of Moscow' => Conservatives
